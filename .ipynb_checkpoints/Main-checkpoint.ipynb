# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %%
# Load the dataset
cath_df = pd.read_csv("./data/cath_moments.tsv", sep='\t', header=None) # For Train
ecod_df = pd.read_csv("./data/ecod_moments.tsv", sep='\t', header=None) # For eval

# %%
cath_info = cath_df.info()

# %%
ecod_info = ecod_df.info()

# %%
# Summarize shapes, classes, and a preview
cath_summary = {
    "shape": cath_df.shape,
    "unique_classes": cath_df[0].nunique(),
    "class_distribution": cath_df[0].value_counts(),
    "head": cath_df.head()
}

ecod_summary = {
    "shape": ecod_df.shape,
    "unique_classes": ecod_df[0].nunique(),
    "class_distribution": ecod_df[0].value_counts(),
    "head": ecod_df.head()
}

# %%
print(cath_summary)

# %%
print(ecod_summary)

# %%
for i in range(0,2):
    print(type(cath_df.iloc[0,i]))

# %%
# Plot class distribution for CATH
cath_class_counts = cath_df[0].value_counts()
plt.figure(figsize=(12, 4))
plt.hist(cath_class_counts, bins=30, edgecolor='black')
plt.title('Class Frequency Distribution in CATH Dataset')
plt.xlabel('Number of proteins per class')
plt.ylabel('Number of classes')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot class distribution for ECOD
ecod_class_counts = ecod_df[0].value_counts()
plt.figure(figsize=(12, 4))
plt.hist(ecod_class_counts, bins=20, edgecolor='black')
plt.title('Class Frequency Distribution in ECOD Dataset')
plt.xlabel('Number of proteins per class')
plt.ylabel('Number of classes')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualizing Class Imbalance
#
# Each protein in the dataset is associated with a structural class label (column 0), which identifies its 3D(1D in this case) shape category. Understanding how many proteins fall into each class is critical because the dataset is not balanced—some classes have many proteins, while others have very few.
#
# To quantify this, we use `value_counts()` to compute the frequency of each class label and visualize the distribution with a histogram.
#
# #### Why this is important:
# During training, we will create pairs of proteins to determine structural similarity. If a particular class contains many proteins, it will generate significantly more pairs, which may bias the model toward frequently occurring classes. This can lead to overfitting and poor generalization, especially on underrepresented classes.
#
# By plotting the class frequency distribution:
# - We confirm whether class imbalance is present.
# - We motivate the need for sampling strategies such as `WeightedRandomSampler` to correct for this imbalance during training.
#
# This analysis is a key step in understanding the structure of the data and informing how we design the training process.

# %%
import pandas as pd
import torch

from train import train_model, test_model_on_ecod

# %%
# Load datasets
cath_df = pd.read_csv("./data/cath_moments.tsv", sep='\t', header=None).dropna(axis=1)
ecod_df = pd.read_csv("./data/ecod_moments.tsv", sep='\t', header=None).dropna(axis=1)

print(f"CATH: {cath_df.shape}, ECOD: {ecod_df.shape}")
# Out:
# CATH: (2685, 3923), ECOD: (761, 3923)

# %%
import pandas as pd
from cache_utils import cache_pairwise_data

df = pd.read_csv("./data/cath_moments.tsv", sep="\t", header=None).dropna(axis=1)
cache_pairwise_data(df.head(2685), cache_dir="./cache/cath_buffered", buffer_limit_mb=100)
# Out:
# Generating pairwise data from 2685 proteins using 12 cores...
# Flushed buffer 0 with 1 items → ./cache/cath_buffered/part_0.pkl
# Flushed buffer 1 with 1000 items → ./cache/cath_buffered/part_1.pkl
# Flushed buffer 2 with 1000 items → ./cache/cath_buffered/part_2.pkl
# Flushed buffer 3 with 1000 items → ./cache/cath_buffered/part_3.pkl
# Flushed buffer 4 with 1000 items → ./cache/cath_buffered/part_4.pkl
# Flushed buffer 5 with 1000 items → ./cache/cath_buffered/part_5.pkl
# Flushed buffer 6 with 1000 items → ./cache/cath_buffered/part_6.pkl
# Flushed buffer 7 with 1000 items → ./cache/cath_buffered/part_7.pkl
# Flushed buffer 8 with 1000 items → ./cache/cath_buffered/part_8.pkl
# Flushed buffer 9 with 1000 items → ./cache/cath_buffered/part_9.pkl
# Flushed buffer 10 with 1000 items → ./cache/cath_buffered/part_10.pkl
# Flushed buffer 11 with 1000 items → ./cache/cath_buffered/part_11.pkl
# Flushed buffer 12 with 1000 items → ./cache/cath_buffered/part_12.pkl
# Flushed buffer 13 with 1000 items → ./cache/cath_buffered/part_13.pkl
# Flushed buffer 14 with 1000 items → ./cache/cath_buffered/part_14.pkl
# Flushed buffer 15 with 1000 items → ./cache/cath_buffered/part_15.pkl
# Flushed buffer 16 with 1000 items → ./cache/cath_buffered/part_16.pkl
# Flushed buffer 17 with 1000 items → ./cache/cath_buffered/part_17.pkl
# Flushed buffer 18 with 1000 items → ./cache/cath_buffered/part_18.pkl
# Flushed buffer 19 with 1000 items → ./cache/cath_buffered/part_19.pkl
# Flushed buffer 20 with 1000 items → ./cache/cath_buffered/part_20.pkl
# Flushed buffer 21 with 1000 items → ./cache/cath_buffered/part_21.pkl
# Flushed buffer 22 with 1000 items → ./cache/cath_buffered/part_22.pkl
# Flushed buffer 23 with 1000 items → ./cache/cath_buffered/part_23.pkl
# Flushed buffer 24 with 1000 items → ./cache/cath_buffered/part_24.pkl
# Flushed buffer 25 with 1000 items → ./cache/cath_buffered/part_25.pkl
# Flushed buffer 26 with 1000 items → ./cache/cath_buffered/part_26.pkl
# Flushed buffer 27 with 1000 items → ./cache/cath_buffered/part_27.pkl
# Flushed buffer 28 with 1000 items → ./cache/cath_buffered/part_28.pkl
# Flushed buffer 29 with 1000 items → ./cache/cath_buffered/part_29.pkl
# Flushed buffer 30 with 1000 items → ./cache/cath_buffered/part_30.pkl
# Flushed buffer 31 with 1000 items → ./cache/cath_buffered/part_31.pkl
# Flushed buffer 32 with 1000 items → ./cache/cath_buffered/part_32.pkl
# Flushed buffer 33 with 1000 items → ./cache/cath_buffered/part_33.pkl
# Flushed buffer 34 with 1000 items → ./cache/cath_buffered/part_34.pkl
# Flushed buffer 35 with 1000 items → ./cache/cath_buffered/part_35.pkl
# Flushed buffer 36 with 1000 items → ./cache/cath_buffered/part_36.pkl
# Flushed buffer 37 with 1000 items → ./cache/cath_buffered/part_37.pkl
# Flushed buffer 38 with 1000 items → ./cache/cath_buffered/part_38.pkl
# Flushed buffer 39 with 1000 items → ./cache/cath_buffered/part_39.pkl
# Flushed buffer 40 with 1000 items → ./cache/cath_buffered/part_40.pkl
# Flushed buffer 41 with 1000 items → ./cache/cath_buffered/part_41.pkl
# Flushed buffer 42 with 1000 items → ./cache/cath_buffered/part_42.pkl
# Flushed buffer 43 with 1000 items → ./cache/cath_buffered/part_43.pkl
# Flushed buffer 44 with 1000 items → ./cache/cath_buffered/part_44.pkl
# Flushed buffer 45 with 1000 items → ./cache/cath_buffered/part_45.pkl
# Flushed buffer 46 with 1000 items → ./cache/cath_buffered/part_46.pkl
# Flushed buffer 47 with 1000 items → ./cache/cath_buffered/part_47.pkl
# Flushed buffer 48 with 1000 items → ./cache/cath_buffered/part_48.pkl
# Flushed buffer 49 with 1000 items → ./cache/cath_buffered/part_49.pkl
# Flushed buffer 50 with 1000 items → ./cache/cath_buffered/part_50.pkl
# Flushed buffer 51 with 1000 items → ./cache/cath_buffered/part_51.pkl
# Flushed buffer 52 with 1000 items → ./cache/cath_buffered/part_52.pkl
# Flushed buffer 53 with 1000 items → ./cache/cath_buffered/part_53.pkl
# Flushed buffer 54 with 1000 items → ./cache/cath_buffered/part_54.pkl
# Flushed buffer 55 with 1000 items → ./cache/cath_buffered/part_55.pkl
# Flushed buffer 56 with 1000 items → ./cache/cath_buffered/part_56.pkl
# Flushed buffer 57 with 1000 items → ./cache/cath_buffered/part_57.pkl
# Flushed buffer 58 with 1000 items → ./cache/cath_buffered/part_58.pkl
# Flushed buffer 59 with 1000 items → ./cache/cath_buffered/part_59.pkl
# Flushed buffer 60 with 1000 items → ./cache/cath_buffered/part_60.pkl
# Flushed buffer 61 with 1000 items → ./cache/cath_buffered/part_61.pkl
# Flushed buffer 62 with 1000 items → ./cache/cath_buffered/part_62.pkl
# Flushed buffer 63 with 1000 items → ./cache/cath_buffered/part_63.pkl
# Flushed buffer 64 with 1000 items → ./cache/cath_buffered/part_64.pkl
# Flushed buffer 65 with 1000 items → ./cache/cath_buffered/part_65.pkl
# Flushed buffer 66 with 1000 items → ./cache/cath_buffered/part_66.pkl
# Flushed buffer 67 with 1000 items → ./cache/cath_buffered/part_67.pkl
# Flushed buffer 68 with 1000 items → ./cache/cath_buffered/part_68.pkl
# Flushed buffer 69 with 1000 items → ./cache/cath_buffered/part_69.pkl
# Flushed buffer 70 with 1000 items → ./cache/cath_buffered/part_70.pkl
# Flushed buffer 71 with 1000 items → ./cache/cath_buffered/part_71.pkl
# Flushed buffer 72 with 1000 items → ./cache/cath_buffered/part_72.pkl
# Flushed buffer 73 with 1000 items → ./cache/cath_buffered/part_73.pkl
# Flushed buffer 74 with 1000 items → ./cache/cath_buffered/part_74.pkl
# Flushed buffer 75 with 1000 items → ./cache/cath_buffered/part_75.pkl
# Flushed buffer 76 with 1000 items → ./cache/cath_buffered/part_76.pkl
# Flushed buffer 77 with 1000 items → ./cache/cath_buffered/part_77.pkl
# Flushed buffer 78 with 1000 items → ./cache/cath_buffered/part_78.pkl
# Flushed buffer 79 with 1000 items → ./cache/cath_buffered/part_79.pkl
# Flushed buffer 80 with 1000 items → ./cache/cath_buffered/part_80.pkl
# Flushed buffer 81 with 1000 items → ./cache/cath_buffered/part_81.pkl
# Flushed buffer 82 with 1000 items → ./cache/cath_buffered/part_82.pkl
# Flushed buffer 83 with 1000 items → ./cache/cath_buffered/part_83.pkl
# Flushed buffer 84 with 1000 items → ./cache/cath_buffered/part_84.pkl
# Flushed buffer 85 with 1000 items → ./cache/cath_buffered/part_85.pkl
# Flushed buffer 86 with 1000 items → ./cache/cath_buffered/part_86.pkl
# Flushed buffer 87 with 1000 items → ./cache/cath_buffered/part_87.pkl
# Flushed buffer 88 with 1000 items → ./cache/cath_buffered/part_88.pkl
# Flushed buffer 89 with 1000 items → ./cache/cath_buffered/part_89.pkl
# Flushed buffer 90 with 1000 items → ./cache/cath_buffered/part_90.pkl
# Flushed buffer 91 with 1000 items → ./cache/cath_buffered/part_91.pkl
# Flushed buffer 92 with 1000 items → ./cache/cath_buffered/part_92.pkl
# Flushed buffer 93 with 1000 items → ./cache/cath_buffered/part_93.pkl
# Flushed buffer 94 with 1000 items → ./cache/cath_buffered/part_94.pkl
# Flushed buffer 95 with 1000 items → ./cache/cath_buffered/part_95.pkl
# Flushed buffer 96 with 1000 items → ./cache/cath_buffered/part_96.pkl
# Flushed buffer 97 with 1000 items → ./cache/cath_buffered/part_97.pkl
# Flushed buffer 98 with 1000 items → ./cache/cath_buffered/part_98.pkl
# Flushed buffer 99 with 1000 items → ./cache/cath_buffered/part_99.pkl
# Flushed buffer 100 with 1000 items → ./cache/cath_buffered/part_100.pkl
# Flushed buffer 101 with 1000 items → ./cache/cath_buffered/part_101.pkl
# Flushed buffer 102 with 1000 items → ./cache/cath_buffered/part_102.pkl
# Flushed buffer 103 with 1000 items → ./cache/cath_buffered/part_103.pkl
# Flushed buffer 104 with 1000 items → ./cache/cath_buffered/part_104.pkl
# Flushed buffer 105 with 1000 items → ./cache/cath_buffered/part_105.pkl
# Flushed buffer 106 with 1000 items → ./cache/cath_buffered/part_106.pkl
# Flushed buffer 107 with 1000 items → ./cache/cath_buffered/part_107.pkl
# Flushed buffer 108 with 1000 items → ./cache/cath_buffered/part_108.pkl
# Flushed buffer 109 with 1000 items → ./cache/cath_buffered/part_109.pkl
# Flushed buffer 110 with 1000 items → ./cache/cath_buffered/part_110.pkl
# Flushed buffer 111 with 1000 items → ./cache/cath_buffered/part_111.pkl
# Flushed buffer 112 with 1000 items → ./cache/cath_buffered/part_112.pkl
# Flushed buffer 113 with 1000 items → ./cache/cath_buffered/part_113.pkl
# Flushed buffer 114 with 1000 items → ./cache/cath_buffered/part_114.pkl
# Flushed buffer 115 with 1000 items → ./cache/cath_buffered/part_115.pkl
# Flushed buffer 116 with 1000 items → ./cache/cath_buffered/part_116.pkl
# Flushed buffer 117 with 1000 items → ./cache/cath_buffered/part_117.pkl
# Flushed buffer 118 with 1000 items → ./cache/cath_buffered/part_118.pkl
# Flushed buffer 119 with 1000 items → ./cache/cath_buffered/part_119.pkl
# Flushed buffer 120 with 1000 items → ./cache/cath_buffered/part_120.pkl
# Flushed buffer 121 with 1000 items → ./cache/cath_buffered/part_121.pkl
# Flushed buffer 122 with 1000 items → ./cache/cath_buffered/part_122.pkl
# Flushed buffer 123 with 1000 items → ./cache/cath_buffered/part_123.pkl
# Flushed buffer 124 with 1000 items → ./cache/cath_buffered/part_124.pkl
# Flushed buffer 125 with 1000 items → ./cache/cath_buffered/part_125.pkl
# Flushed buffer 126 with 1000 items → ./cache/cath_buffered/part_126.pkl
# Flushed buffer 127 with 1000 items → ./cache/cath_buffered/part_127.pkl
# Flushed buffer 128 with 1000 items → ./cache/cath_buffered/part_128.pkl
# Flushed buffer 129 with 1000 items → ./cache/cath_buffered/part_129.pkl
# Flushed buffer 130 with 1000 items → ./cache/cath_buffered/part_130.pkl
# Flushed buffer 131 with 1000 items → ./cache/cath_buffered/part_131.pkl
# Flushed buffer 132 with 1000 items → ./cache/cath_buffered/part_132.pkl
# Flushed buffer 133 with 1000 items → ./cache/cath_buffered/part_133.pkl
# Flushed buffer 134 with 1000 items → ./cache/cath_buffered/part_134.pkl
# Flushed buffer 135 with 1000 items → ./cache/cath_buffered/part_135.pkl
# Flushed buffer 136 with 1000 items → ./cache/cath_buffered/part_136.pkl
# Flushed buffer 137 with 1000 items → ./cache/cath_buffered/part_137.pkl
# Flushed buffer 138 with 1000 items → ./cache/cath_buffered/part_138.pkl
# Flushed buffer 139 with 1000 items → ./cache/cath_buffered/part_139.pkl
# Flushed buffer 140 with 1000 items → ./cache/cath_buffered/part_140.pkl
# Flushed buffer 141 with 1000 items → ./cache/cath_buffered/part_141.pkl
# Flushed buffer 142 with 1000 items → ./cache/cath_buffered/part_142.pkl
# Flushed buffer 143 with 1000 items → ./cache/cath_buffered/part_143.pkl
# Flushed buffer 144 with 1000 items → ./cache/cath_buffered/part_144.pkl
# Flushed buffer 145 with 1000 items → ./cache/cath_buffered/part_145.pkl
# Flushed buffer 146 with 1000 items → ./cache/cath_buffered/part_146.pkl
# Flushed buffer 147 with 1000 items → ./cache/cath_buffered/part_147.pkl
# Flushed buffer 148 with 1000 items → ./cache/cath_buffered/part_148.pkl
# Flushed buffer 149 with 1000 items → ./cache/cath_buffered/part_149.pkl
# Flushed buffer 150 with 1000 items → ./cache/cath_buffered/part_150.pkl
# Flushed buffer 151 with 1000 items → ./cache/cath_buffered/part_151.pkl
# Flushed buffer 152 with 1000 items → ./cache/cath_buffered/part_152.pkl
# Flushed buffer 153 with 1000 items → ./cache/cath_buffered/part_153.pkl
# Flushed buffer 154 with 1000 items → ./cache/cath_buffered/part_154.pkl
# Flushed buffer 155 with 1000 items → ./cache/cath_buffered/part_155.pkl
# Flushed buffer 156 with 1000 items → ./cache/cath_buffered/part_156.pkl
# Flushed buffer 157 with 1000 items → ./cache/cath_buffered/part_157.pkl
# Flushed buffer 158 with 1000 items → ./cache/cath_buffered/part_158.pkl
# Flushed buffer 159 with 1000 items → ./cache/cath_buffered/part_159.pkl
# Flushed buffer 160 with 1000 items → ./cache/cath_buffered/part_160.pkl
# Flushed buffer 161 with 1000 items → ./cache/cath_buffered/part_161.pkl
# Flushed buffer 162 with 1000 items → ./cache/cath_buffered/part_162.pkl
# Flushed buffer 163 with 1000 items → ./cache/cath_buffered/part_163.pkl
# Flushed buffer 164 with 1000 items → ./cache/cath_buffered/part_164.pkl
# Flushed buffer 165 with 1000 items → ./cache/cath_buffered/part_165.pkl
# Flushed buffer 166 with 1000 items → ./cache/cath_buffered/part_166.pkl
# Flushed buffer 167 with 1000 items → ./cache/cath_buffered/part_167.pkl
# Flushed buffer 168 with 1000 items → ./cache/cath_buffered/part_168.pkl
# Flushed buffer 169 with 1000 items → ./cache/cath_buffered/part_169.pkl
# Flushed buffer 170 with 1000 items → ./cache/cath_buffered/part_170.pkl
# Flushed buffer 171 with 1000 items → ./cache/cath_buffered/part_171.pkl
# Flushed buffer 172 with 1000 items → ./cache/cath_buffered/part_172.pkl
# Flushed buffer 173 with 1000 items → ./cache/cath_buffered/part_173.pkl
# Flushed buffer 174 with 1000 items → ./cache/cath_buffered/part_174.pkl
# Flushed buffer 175 with 1000 items → ./cache/cath_buffered/part_175.pkl
# Flushed buffer 176 with 1000 items → ./cache/cath_buffered/part_176.pkl
# Flushed buffer 177 with 1000 items → ./cache/cath_buffered/part_177.pkl
# Flushed buffer 178 with 1000 items → ./cache/cath_buffered/part_178.pkl
# Flushed buffer 179 with 1000 items → ./cache/cath_buffered/part_179.pkl
# Flushed buffer 180 with 1000 items → ./cache/cath_buffered/part_180.pkl
# Flushed buffer 181 with 1000 items → ./cache/cath_buffered/part_181.pkl
# Flushed buffer 182 with 1000 items → ./cache/cath_buffered/part_182.pkl
# Flushed buffer 183 with 1000 items → ./cache/cath_buffered/part_183.pkl
# Flushed buffer 184 with 1000 items → ./cache/cath_buffered/part_184.pkl
# Flushed buffer 185 with 1000 items → ./cache/cath_buffered/part_185.pkl
# Flushed buffer 186 with 1000 items → ./cache/cath_buffered/part_186.pkl
# Flushed buffer 187 with 1000 items → ./cache/cath_buffered/part_187.pkl
# Flushed buffer 188 with 1000 items → ./cache/cath_buffered/part_188.pkl
# Flushed buffer 189 with 1000 items → ./cache/cath_buffered/part_189.pkl
# Flushed buffer 190 with 1000 items → ./cache/cath_buffered/part_190.pkl
# Flushed buffer 191 with 1000 items → ./cache/cath_buffered/part_191.pkl
# Flushed buffer 192 with 1000 items → ./cache/cath_buffered/part_192.pkl
# Flushed buffer 193 with 1000 items → ./cache/cath_buffered/part_193.pkl
# Flushed buffer 194 with 1000 items → ./cache/cath_buffered/part_194.pkl
# Flushed buffer 195 with 1000 items → ./cache/cath_buffered/part_195.pkl
# Flushed buffer 196 with 1000 items → ./cache/cath_buffered/part_196.pkl
# Flushed buffer 197 with 1000 items → ./cache/cath_buffered/part_197.pkl
# Flushed buffer 198 with 1000 items → ./cache/cath_buffered/part_198.pkl
# Flushed buffer 199 with 1000 items → ./cache/cath_buffered/part_199.pkl
# Flushed buffer 200 with 1000 items → ./cache/cath_buffered/part_200.pkl
# Flushed buffer 201 with 1000 items → ./cache/cath_buffered/part_201.pkl
# Flushed buffer 202 with 1000 items → ./cache/cath_buffered/part_202.pkl
# Flushed buffer 203 with 1000 items → ./cache/cath_buffered/part_203.pkl
# Flushed buffer 204 with 1000 items → ./cache/cath_buffered/part_204.pkl
# Flushed buffer 205 with 1000 items → ./cache/cath_buffered/part_205.pkl
# Flushed buffer 206 with 1000 items → ./cache/cath_buffered/part_206.pkl
# Flushed buffer 207 with 1000 items → ./cache/cath_buffered/part_207.pkl
# Flushed buffer 208 with 1000 items → ./cache/cath_buffered/part_208.pkl
# Flushed buffer 209 with 1000 items → ./cache/cath_buffered/part_209.pkl
# Flushed buffer 210 with 1000 items → ./cache/cath_buffered/part_210.pkl
# Flushed buffer 211 with 1000 items → ./cache/cath_buffered/part_211.pkl
# Flushed buffer 212 with 1000 items → ./cache/cath_buffered/part_212.pkl
# Flushed buffer 213 with 1000 items → ./cache/cath_buffered/part_213.pkl
# Flushed buffer 214 with 1000 items → ./cache/cath_buffered/part_214.pkl
# Flushed buffer 215 with 1000 items → ./cache/cath_buffered/part_215.pkl
# Flushed buffer 216 with 1000 items → ./cache/cath_buffered/part_216.pkl
# Flushed buffer 217 with 1000 items → ./cache/cath_buffered/part_217.pkl
# Flushed buffer 218 with 1000 items → ./cache/cath_buffered/part_218.pkl
# Flushed buffer 219 with 1000 items → ./cache/cath_buffered/part_219.pkl
# Flushed buffer 220 with 1000 items → ./cache/cath_buffered/part_220.pkl
# Flushed buffer 221 with 1000 items → ./cache/cath_buffered/part_221.pkl
# Flushed buffer 222 with 1000 items → ./cache/cath_buffered/part_222.pkl
# Flushed buffer 223 with 1000 items → ./cache/cath_buffered/part_223.pkl
# Flushed buffer 224 with 1000 items → ./cache/cath_buffered/part_224.pkl
# Flushed buffer 225 with 1000 items → ./cache/cath_buffered/part_225.pkl
# Flushed buffer 226 with 1000 items → ./cache/cath_buffered/part_226.pkl
# Flushed buffer 227 with 1000 items → ./cache/cath_buffered/part_227.pkl
# Flushed buffer 228 with 1000 items → ./cache/cath_buffered/part_228.pkl
# Flushed buffer 229 with 1000 items → ./cache/cath_buffered/part_229.pkl
# Flushed buffer 230 with 1000 items → ./cache/cath_buffered/part_230.pkl
# Flushed buffer 231 with 1000 items → ./cache/cath_buffered/part_231.pkl
# Flushed buffer 232 with 1000 items → ./cache/cath_buffered/part_232.pkl
# Flushed buffer 233 with 1000 items → ./cache/cath_buffered/part_233.pkl
# Flushed buffer 234 with 1000 items → ./cache/cath_buffered/part_234.pkl
# Flushed buffer 235 with 1000 items → ./cache/cath_buffered/part_235.pkl
# Flushed buffer 236 with 1000 items → ./cache/cath_buffered/part_236.pkl
# Flushed buffer 237 with 1000 items → ./cache/cath_buffered/part_237.pkl
# Flushed buffer 238 with 1000 items → ./cache/cath_buffered/part_238.pkl
# Flushed buffer 239 with 1000 items → ./cache/cath_buffered/part_239.pkl
# Flushed buffer 240 with 1000 items → ./cache/cath_buffered/part_240.pkl
# Flushed buffer 241 with 1000 items → ./cache/cath_buffered/part_241.pkl
# Flushed buffer 242 with 1000 items → ./cache/cath_buffered/part_242.pkl
# Flushed buffer 243 with 1000 items → ./cache/cath_buffered/part_243.pkl
# Flushed buffer 244 with 1000 items → ./cache/cath_buffered/part_244.pkl
# Flushed buffer 245 with 1000 items → ./cache/cath_buffered/part_245.pkl
# Flushed buffer 246 with 1000 items → ./cache/cath_buffered/part_246.pkl
# Flushed buffer 247 with 1000 items → ./cache/cath_buffered/part_247.pkl
# Flushed buffer 248 with 1000 items → ./cache/cath_buffered/part_248.pkl
# Flushed buffer 249 with 1000 items → ./cache/cath_buffered/part_249.pkl
# Flushed buffer 250 with 1000 items → ./cache/cath_buffered/part_250.pkl
# Flushed buffer 251 with 1000 items → ./cache/cath_buffered/part_251.pkl
# Flushed buffer 252 with 1000 items → ./cache/cath_buffered/part_252.pkl
# Flushed buffer 253 with 1000 items → ./cache/cath_buffered/part_253.pkl
# Flushed buffer 254 with 1000 items → ./cache/cath_buffered/part_254.pkl
# Flushed buffer 255 with 1000 items → ./cache/cath_buffered/part_255.pkl
# Flushed buffer 256 with 1000 items → ./cache/cath_buffered/part_256.pkl
# Flushed buffer 257 with 1000 items → ./cache/cath_buffered/part_257.pkl
# Flushed buffer 258 with 1000 items → ./cache/cath_buffered/part_258.pkl
# Flushed buffer 259 with 1000 items → ./cache/cath_buffered/part_259.pkl
# Flushed buffer 260 with 1000 items → ./cache/cath_buffered/part_260.pkl
# Flushed buffer 261 with 1000 items → ./cache/cath_buffered/part_261.pkl
# Flushed buffer 262 with 1000 items → ./cache/cath_buffered/part_262.pkl
# Flushed buffer 263 with 1000 items → ./cache/cath_buffered/part_263.pkl
# Flushed buffer 264 with 1000 items → ./cache/cath_buffered/part_264.pkl
# Flushed buffer 265 with 1000 items → ./cache/cath_buffered/part_265.pkl
# Flushed buffer 266 with 1000 items → ./cache/cath_buffered/part_266.pkl
# Flushed buffer 267 with 1000 items → ./cache/cath_buffered/part_267.pkl
# Flushed buffer 268 with 1000 items → ./cache/cath_buffered/part_268.pkl
# Flushed buffer 269 with 1000 items → ./cache/cath_buffered/part_269.pkl
# Flushed buffer 270 with 1000 items → ./cache/cath_buffered/part_270.pkl
# Flushed buffer 271 with 1000 items → ./cache/cath_buffered/part_271.pkl
# Flushed buffer 272 with 1000 items → ./cache/cath_buffered/part_272.pkl
# Flushed buffer 273 with 1000 items → ./cache/cath_buffered/part_273.pkl
# Flushed buffer 274 with 1000 items → ./cache/cath_buffered/part_274.pkl
# Flushed buffer 275 with 1000 items → ./cache/cath_buffered/part_275.pkl
# Flushed buffer 276 with 1000 items → ./cache/cath_buffered/part_276.pkl
# Flushed buffer 277 with 1000 items → ./cache/cath_buffered/part_277.pkl
# Flushed buffer 278 with 1000 items → ./cache/cath_buffered/part_278.pkl
# Flushed buffer 279 with 1000 items → ./cache/cath_buffered/part_279.pkl
# Flushed buffer 280 with 1000 items → ./cache/cath_buffered/part_280.pkl
# Flushed buffer 281 with 1000 items → ./cache/cath_buffered/part_281.pkl
# Flushed buffer 282 with 1000 items → ./cache/cath_buffered/part_282.pkl
# Flushed buffer 283 with 1000 items → ./cache/cath_buffered/part_283.pkl
# Flushed buffer 284 with 1000 items → ./cache/cath_buffered/part_284.pkl
# Flushed buffer 285 with 1000 items → ./cache/cath_buffered/part_285.pkl
# Flushed buffer 286 with 1000 items → ./cache/cath_buffered/part_286.pkl
# Flushed buffer 287 with 1000 items → ./cache/cath_buffered/part_287.pkl
# Flushed buffer 288 with 1000 items → ./cache/cath_buffered/part_288.pkl
# Flushed buffer 289 with 1000 items → ./cache/cath_buffered/part_289.pkl
# Flushed buffer 290 with 1000 items → ./cache/cath_buffered/part_290.pkl
# Flushed buffer 291 with 1000 items → ./cache/cath_buffered/part_291.pkl
# Flushed buffer 292 with 1000 items → ./cache/cath_buffered/part_292.pkl
# Flushed buffer 293 with 1000 items → ./cache/cath_buffered/part_293.pkl
# Flushed buffer 294 with 1000 items → ./cache/cath_buffered/part_294.pkl
# Flushed buffer 295 with 1000 items → ./cache/cath_buffered/part_295.pkl
# Flushed buffer 296 with 1000 items → ./cache/cath_buffered/part_296.pkl
# Flushed buffer 297 with 1000 items → ./cache/cath_buffered/part_297.pkl
# Flushed buffer 298 with 1000 items → ./cache/cath_buffered/part_298.pkl
# Flushed buffer 299 with 1000 items → ./cache/cath_buffered/part_299.pkl
# Flushed buffer 300 with 1000 items → ./cache/cath_buffered/part_300.pkl
# Flushed buffer 301 with 1000 items → ./cache/cath_buffered/part_301.pkl
# Flushed buffer 302 with 1000 items → ./cache/cath_buffered/part_302.pkl
# Flushed buffer 303 with 1000 items → ./cache/cath_buffered/part_303.pkl
# Flushed buffer 304 with 1000 items → ./cache/cath_buffered/part_304.pkl
# Flushed buffer 305 with 1000 items → ./cache/cath_buffered/part_305.pkl
# Flushed buffer 306 with 1000 items → ./cache/cath_buffered/part_306.pkl
# Flushed buffer 307 with 1000 items → ./cache/cath_buffered/part_307.pkl
# Flushed buffer 308 with 1000 items → ./cache/cath_buffered/part_308.pkl
# Flushed buffer 309 with 1000 items → ./cache/cath_buffered/part_309.pkl
# Flushed buffer 310 with 1000 items → ./cache/cath_buffered/part_310.pkl
# Flushed buffer 311 with 1000 items → ./cache/cath_buffered/part_311.pkl
# Flushed buffer 312 with 1000 items → ./cache/cath_buffered/part_312.pkl
# Flushed buffer 313 with 1000 items → ./cache/cath_buffered/part_313.pkl
# Flushed buffer 314 with 1000 items → ./cache/cath_buffered/part_314.pkl
# Flushed buffer 315 with 1000 items → ./cache/cath_buffered/part_315.pkl
# Flushed buffer 316 with 1000 items → ./cache/cath_buffered/part_316.pkl
# Flushed buffer 317 with 1000 items → ./cache/cath_buffered/part_317.pkl
# Flushed buffer 318 with 1000 items → ./cache/cath_buffered/part_318.pkl
# Flushed buffer 319 with 1000 items → ./cache/cath_buffered/part_319.pkl
# Flushed buffer 320 with 1000 items → ./cache/cath_buffered/part_320.pkl
# Flushed buffer 321 with 1000 items → ./cache/cath_buffered/part_321.pkl
# Flushed buffer 322 with 1000 items → ./cache/cath_buffered/part_322.pkl
# Flushed buffer 323 with 1000 items → ./cache/cath_buffered/part_323.pkl
# Flushed buffer 324 with 1000 items → ./cache/cath_buffered/part_324.pkl
# Flushed buffer 325 with 1000 items → ./cache/cath_buffered/part_325.pkl
# Flushed buffer 326 with 1000 items → ./cache/cath_buffered/part_326.pkl
# Flushed buffer 327 with 1000 items → ./cache/cath_buffered/part_327.pkl
# Flushed buffer 328 with 1000 items → ./cache/cath_buffered/part_328.pkl
# Flushed buffer 329 with 1000 items → ./cache/cath_buffered/part_329.pkl
# Flushed buffer 330 with 1000 items → ./cache/cath_buffered/part_330.pkl
# Flushed buffer 331 with 1000 items → ./cache/cath_buffered/part_331.pkl
# Flushed buffer 332 with 1000 items → ./cache/cath_buffered/part_332.pkl
# Flushed buffer 333 with 1000 items → ./cache/cath_buffered/part_333.pkl
# Flushed buffer 334 with 1000 items → ./cache/cath_buffered/part_334.pkl
# Flushed buffer 335 with 1000 items → ./cache/cath_buffered/part_335.pkl
# Flushed buffer 336 with 1000 items → ./cache/cath_buffered/part_336.pkl
# Flushed buffer 337 with 1000 items → ./cache/cath_buffered/part_337.pkl
# Flushed buffer 338 with 1000 items → ./cache/cath_buffered/part_338.pkl
# Flushed buffer 339 with 1000 items → ./cache/cath_buffered/part_339.pkl
# Flushed buffer 340 with 1000 items → ./cache/cath_buffered/part_340.pkl
# Flushed buffer 341 with 1000 items → ./cache/cath_buffered/part_341.pkl
# Flushed buffer 342 with 1000 items → ./cache/cath_buffered/part_342.pkl
# Flushed buffer 343 with 1000 items → ./cache/cath_buffered/part_343.pkl
# Flushed buffer 344 with 1000 items → ./cache/cath_buffered/part_344.pkl
# Flushed buffer 345 with 1000 items → ./cache/cath_buffered/part_345.pkl
# Flushed buffer 346 with 1000 items → ./cache/cath_buffered/part_346.pkl
# Flushed buffer 347 with 1000 items → ./cache/cath_buffered/part_347.pkl
# Flushed buffer 348 with 1000 items → ./cache/cath_buffered/part_348.pkl
# Flushed buffer 349 with 1000 items → ./cache/cath_buffered/part_349.pkl
# Flushed buffer 350 with 1000 items → ./cache/cath_buffered/part_350.pkl
# Flushed buffer 351 with 1000 items → ./cache/cath_buffered/part_351.pkl
# Flushed buffer 352 with 1000 items → ./cache/cath_buffered/part_352.pkl
# Flushed buffer 353 with 1000 items → ./cache/cath_buffered/part_353.pkl
# Flushed buffer 354 with 1000 items → ./cache/cath_buffered/part_354.pkl
# Flushed buffer 355 with 1000 items → ./cache/cath_buffered/part_355.pkl
# Flushed buffer 356 with 1000 items → ./cache/cath_buffered/part_356.pkl
# Flushed buffer 357 with 1000 items → ./cache/cath_buffered/part_357.pkl
# Flushed buffer 358 with 1000 items → ./cache/cath_buffered/part_358.pkl
# Flushed buffer 359 with 1000 items → ./cache/cath_buffered/part_359.pkl
# Flushed buffer 360 with 1000 items → ./cache/cath_buffered/part_360.pkl
# Flushed buffer 361 with 1000 items → ./cache/cath_buffered/part_361.pkl
# Flushed buffer 362 with 1000 items → ./cache/cath_buffered/part_362.pkl
# Flushed buffer 363 with 1000 items → ./cache/cath_buffered/part_363.pkl
# Flushed buffer 364 with 1000 items → ./cache/cath_buffered/part_364.pkl
# Flushed buffer 365 with 1000 items → ./cache/cath_buffered/part_365.pkl
# Flushed buffer 366 with 1000 items → ./cache/cath_buffered/part_366.pkl
# Flushed buffer 367 with 1000 items → ./cache/cath_buffered/part_367.pkl
# Flushed buffer 368 with 1000 items → ./cache/cath_buffered/part_368.pkl
# Flushed buffer 369 with 1000 items → ./cache/cath_buffered/part_369.pkl
# Flushed buffer 370 with 1000 items → ./cache/cath_buffered/part_370.pkl
# Flushed buffer 371 with 1000 items → ./cache/cath_buffered/part_371.pkl
# Flushed buffer 372 with 1000 items → ./cache/cath_buffered/part_372.pkl
# Flushed buffer 373 with 1000 items → ./cache/cath_buffered/part_373.pkl
# Flushed buffer 374 with 1000 items → ./cache/cath_buffered/part_374.pkl
# Flushed buffer 375 with 1000 items → ./cache/cath_buffered/part_375.pkl
# Flushed buffer 376 with 1000 items → ./cache/cath_buffered/part_376.pkl
# Flushed buffer 377 with 1000 items → ./cache/cath_buffered/part_377.pkl
# Flushed buffer 378 with 1000 items → ./cache/cath_buffered/part_378.pkl
# Flushed buffer 379 with 1000 items → ./cache/cath_buffered/part_379.pkl
# Flushed buffer 380 with 1000 items → ./cache/cath_buffered/part_380.pkl
# Flushed buffer 381 with 1000 items → ./cache/cath_buffered/part_381.pkl
# Flushed buffer 382 with 1000 items → ./cache/cath_buffered/part_382.pkl
# Flushed buffer 383 with 1000 items → ./cache/cath_buffered/part_383.pkl
# Flushed buffer 384 with 1000 items → ./cache/cath_buffered/part_384.pkl
# Flushed buffer 385 with 1000 items → ./cache/cath_buffered/part_385.pkl
# Flushed buffer 386 with 1000 items → ./cache/cath_buffered/part_386.pkl
# Flushed buffer 387 with 1000 items → ./cache/cath_buffered/part_387.pkl
# Flushed buffer 388 with 1000 items → ./cache/cath_buffered/part_388.pkl
# Flushed buffer 389 with 1000 items → ./cache/cath_buffered/part_389.pkl
# Flushed buffer 390 with 1000 items → ./cache/cath_buffered/part_390.pkl
# Flushed buffer 391 with 1000 items → ./cache/cath_buffered/part_391.pkl
# Flushed buffer 392 with 1000 items → ./cache/cath_buffered/part_392.pkl
# Flushed buffer 393 with 1000 items → ./cache/cath_buffered/part_393.pkl
# Flushed buffer 394 with 1000 items → ./cache/cath_buffered/part_394.pkl
# Flushed buffer 395 with 1000 items → ./cache/cath_buffered/part_395.pkl
# Flushed buffer 396 with 1000 items → ./cache/cath_buffered/part_396.pkl
# Flushed buffer 397 with 1000 items → ./cache/cath_buffered/part_397.pkl
# Flushed buffer 398 with 1000 items → ./cache/cath_buffered/part_398.pkl
# Flushed buffer 399 with 1000 items → ./cache/cath_buffered/part_399.pkl
# Flushed buffer 400 with 1000 items → ./cache/cath_buffered/part_400.pkl
# Flushed buffer 401 with 1000 items → ./cache/cath_buffered/part_401.pkl
# Flushed buffer 402 with 1000 items → ./cache/cath_buffered/part_402.pkl
# Flushed buffer 403 with 1000 items → ./cache/cath_buffered/part_403.pkl
# Flushed buffer 404 with 1000 items → ./cache/cath_buffered/part_404.pkl
# Flushed buffer 405 with 1000 items → ./cache/cath_buffered/part_405.pkl
# Flushed buffer 406 with 1000 items → ./cache/cath_buffered/part_406.pkl
# Flushed buffer 407 with 1000 items → ./cache/cath_buffered/part_407.pkl
# Flushed buffer 408 with 1000 items → ./cache/cath_buffered/part_408.pkl
# Flushed buffer 409 with 1000 items → ./cache/cath_buffered/part_409.pkl
# Flushed buffer 410 with 1000 items → ./cache/cath_buffered/part_410.pkl
# Flushed buffer 411 with 1000 items → ./cache/cath_buffered/part_411.pkl
# Flushed buffer 412 with 1000 items → ./cache/cath_buffered/part_412.pkl
# Flushed buffer 413 with 1000 items → ./cache/cath_buffered/part_413.pkl
# Flushed buffer 414 with 1000 items → ./cache/cath_buffered/part_414.pkl
# Flushed buffer 415 with 1000 items → ./cache/cath_buffered/part_415.pkl
# Flushed buffer 416 with 1000 items → ./cache/cath_buffered/part_416.pkl
# Flushed buffer 417 with 1000 items → ./cache/cath_buffered/part_417.pkl
# Flushed buffer 418 with 1000 items → ./cache/cath_buffered/part_418.pkl
# Flushed buffer 419 with 1000 items → ./cache/cath_buffered/part_419.pkl
# Flushed buffer 420 with 1000 items → ./cache/cath_buffered/part_420.pkl
# Flushed buffer 421 with 1000 items → ./cache/cath_buffered/part_421.pkl
# Flushed buffer 422 with 1000 items → ./cache/cath_buffered/part_422.pkl
# Flushed buffer 423 with 1000 items → ./cache/cath_buffered/part_423.pkl
# Flushed buffer 424 with 1000 items → ./cache/cath_buffered/part_424.pkl
# Flushed buffer 425 with 1000 items → ./cache/cath_buffered/part_425.pkl
# Flushed buffer 426 with 1000 items → ./cache/cath_buffered/part_426.pkl
# Flushed buffer 427 with 1000 items → ./cache/cath_buffered/part_427.pkl
# Flushed buffer 428 with 1000 items → ./cache/cath_buffered/part_428.pkl
# Flushed buffer 429 with 1000 items → ./cache/cath_buffered/part_429.pkl
# Flushed buffer 430 with 1000 items → ./cache/cath_buffered/part_430.pkl
# Flushed buffer 431 with 1000 items → ./cache/cath_buffered/part_431.pkl
# Flushed buffer 432 with 1000 items → ./cache/cath_buffered/part_432.pkl
# Flushed buffer 433 with 1000 items → ./cache/cath_buffered/part_433.pkl
# Flushed buffer 434 with 1000 items → ./cache/cath_buffered/part_434.pkl
# Flushed buffer 435 with 1000 items → ./cache/cath_buffered/part_435.pkl
# Flushed buffer 436 with 1000 items → ./cache/cath_buffered/part_436.pkl
# Flushed buffer 437 with 1000 items → ./cache/cath_buffered/part_437.pkl
# Flushed buffer 438 with 1000 items → ./cache/cath_buffered/part_438.pkl
# Flushed buffer 439 with 1000 items → ./cache/cath_buffered/part_439.pkl
# Flushed buffer 440 with 1000 items → ./cache/cath_buffered/part_440.pkl
# Flushed buffer 441 with 1000 items → ./cache/cath_buffered/part_441.pkl
# Flushed buffer 442 with 1000 items → ./cache/cath_buffered/part_442.pkl
# Flushed buffer 443 with 1000 items → ./cache/cath_buffered/part_443.pkl
# Flushed buffer 444 with 1000 items → ./cache/cath_buffered/part_444.pkl
# Flushed buffer 445 with 1000 items → ./cache/cath_buffered/part_445.pkl
# Flushed buffer 446 with 1000 items → ./cache/cath_buffered/part_446.pkl
# Flushed buffer 447 with 1000 items → ./cache/cath_buffered/part_447.pkl
# Flushed buffer 448 with 1000 items → ./cache/cath_buffered/part_448.pkl
# Flushed buffer 449 with 1000 items → ./cache/cath_buffered/part_449.pkl
# Flushed buffer 450 with 1000 items → ./cache/cath_buffered/part_450.pkl
# Flushed buffer 451 with 1000 items → ./cache/cath_buffered/part_451.pkl
# Flushed buffer 452 with 1000 items → ./cache/cath_buffered/part_452.pkl
# Flushed buffer 453 with 1000 items → ./cache/cath_buffered/part_453.pkl
# Flushed buffer 454 with 1000 items → ./cache/cath_buffered/part_454.pkl
# Flushed buffer 455 with 1000 items → ./cache/cath_buffered/part_455.pkl
# Flushed buffer 456 with 1000 items → ./cache/cath_buffered/part_456.pkl
# Flushed buffer 457 with 1000 items → ./cache/cath_buffered/part_457.pkl
# Flushed buffer 458 with 1000 items → ./cache/cath_buffered/part_458.pkl
# Flushed buffer 459 with 1000 items → ./cache/cath_buffered/part_459.pkl
# Flushed buffer 460 with 1000 items → ./cache/cath_buffered/part_460.pkl
# Flushed buffer 461 with 1000 items → ./cache/cath_buffered/part_461.pkl
# Flushed buffer 462 with 1000 items → ./cache/cath_buffered/part_462.pkl
# Flushed buffer 463 with 1000 items → ./cache/cath_buffered/part_463.pkl
# Flushed buffer 464 with 1000 items → ./cache/cath_buffered/part_464.pkl
# Flushed buffer 465 with 1000 items → ./cache/cath_buffered/part_465.pkl
# Flushed buffer 466 with 1000 items → ./cache/cath_buffered/part_466.pkl
# Flushed buffer 467 with 1000 items → ./cache/cath_buffered/part_467.pkl
# Flushed buffer 468 with 1000 items → ./cache/cath_buffered/part_468.pkl
# Flushed buffer 469 with 1000 items → ./cache/cath_buffered/part_469.pkl
# Flushed buffer 470 with 1000 items → ./cache/cath_buffered/part_470.pkl
# Flushed buffer 471 with 1000 items → ./cache/cath_buffered/part_471.pkl
# Flushed buffer 472 with 1000 items → ./cache/cath_buffered/part_472.pkl
# Flushed buffer 473 with 1000 items → ./cache/cath_buffered/part_473.pkl
# Flushed buffer 474 with 1000 items → ./cache/cath_buffered/part_474.pkl
# Flushed buffer 475 with 1000 items → ./cache/cath_buffered/part_475.pkl
# Flushed buffer 476 with 1000 items → ./cache/cath_buffered/part_476.pkl
# Flushed buffer 477 with 1000 items → ./cache/cath_buffered/part_477.pkl
# Flushed buffer 478 with 1000 items → ./cache/cath_buffered/part_478.pkl
# Flushed buffer 479 with 1000 items → ./cache/cath_buffered/part_479.pkl
# Flushed buffer 480 with 1000 items → ./cache/cath_buffered/part_480.pkl
# Flushed buffer 481 with 1000 items → ./cache/cath_buffered/part_481.pkl
# Flushed buffer 482 with 1000 items → ./cache/cath_buffered/part_482.pkl
# Flushed buffer 483 with 1000 items → ./cache/cath_buffered/part_483.pkl
# Flushed buffer 484 with 1000 items → ./cache/cath_buffered/part_484.pkl
# Flushed buffer 485 with 1000 items → ./cache/cath_buffered/part_485.pkl
# Flushed buffer 486 with 1000 items → ./cache/cath_buffered/part_486.pkl
# Flushed buffer 487 with 1000 items → ./cache/cath_buffered/part_487.pkl
# Flushed buffer 488 with 1000 items → ./cache/cath_buffered/part_488.pkl
# Flushed buffer 489 with 1000 items → ./cache/cath_buffered/part_489.pkl
# Flushed buffer 490 with 1000 items → ./cache/cath_buffered/part_490.pkl
# Flushed buffer 491 with 1000 items → ./cache/cath_buffered/part_491.pkl
# Flushed buffer 492 with 1000 items → ./cache/cath_buffered/part_492.pkl
# Flushed buffer 493 with 1000 items → ./cache/cath_buffered/part_493.pkl
# Flushed buffer 494 with 1000 items → ./cache/cath_buffered/part_494.pkl
# Flushed buffer 495 with 1000 items → ./cache/cath_buffered/part_495.pkl
# Flushed buffer 496 with 1000 items → ./cache/cath_buffered/part_496.pkl
# Flushed buffer 497 with 1000 items → ./cache/cath_buffered/part_497.pkl
# Flushed buffer 498 with 1000 items → ./cache/cath_buffered/part_498.pkl
# Flushed buffer 499 with 1000 items → ./cache/cath_buffered/part_499.pkl
# Flushed buffer 500 with 1000 items → ./cache/cath_buffered/part_500.pkl
# Flushed buffer 501 with 1000 items → ./cache/cath_buffered/part_501.pkl
# Flushed buffer 502 with 1000 items → ./cache/cath_buffered/part_502.pkl
# Flushed buffer 503 with 1000 items → ./cache/cath_buffered/part_503.pkl
# Flushed buffer 504 with 1000 items → ./cache/cath_buffered/part_504.pkl
# Flushed buffer 505 with 1000 items → ./cache/cath_buffered/part_505.pkl
# Flushed buffer 506 with 1000 items → ./cache/cath_buffered/part_506.pkl
# Flushed buffer 507 with 1000 items → ./cache/cath_buffered/part_507.pkl
# Flushed buffer 508 with 1000 items → ./cache/cath_buffered/part_508.pkl
# Flushed buffer 509 with 1000 items → ./cache/cath_buffered/part_509.pkl
# Flushed buffer 510 with 1000 items → ./cache/cath_buffered/part_510.pkl
# Flushed buffer 511 with 1000 items → ./cache/cath_buffered/part_511.pkl
# Flushed buffer 512 with 1000 items → ./cache/cath_buffered/part_512.pkl
# Flushed buffer 513 with 1000 items → ./cache/cath_buffered/part_513.pkl
# Flushed buffer 514 with 1000 items → ./cache/cath_buffered/part_514.pkl
# Flushed buffer 515 with 1000 items → ./cache/cath_buffered/part_515.pkl
# Flushed buffer 516 with 1000 items → ./cache/cath_buffered/part_516.pkl
# Flushed buffer 517 with 1000 items → ./cache/cath_buffered/part_517.pkl
# Flushed buffer 518 with 1000 items → ./cache/cath_buffered/part_518.pkl
# Flushed buffer 519 with 1000 items → ./cache/cath_buffered/part_519.pkl
# Flushed buffer 520 with 1000 items → ./cache/cath_buffered/part_520.pkl
# Flushed buffer 521 with 1000 items → ./cache/cath_buffered/part_521.pkl
# Flushed buffer 522 with 1000 items → ./cache/cath_buffered/part_522.pkl
# Flushed buffer 523 with 1000 items → ./cache/cath_buffered/part_523.pkl
# Flushed buffer 524 with 1000 items → ./cache/cath_buffered/part_524.pkl
# Flushed buffer 525 with 1000 items → ./cache/cath_buffered/part_525.pkl
# Flushed buffer 526 with 1000 items → ./cache/cath_buffered/part_526.pkl
# Flushed buffer 527 with 1000 items → ./cache/cath_buffered/part_527.pkl
# Flushed buffer 528 with 1000 items → ./cache/cath_buffered/part_528.pkl
# Flushed buffer 529 with 1000 items → ./cache/cath_buffered/part_529.pkl
# Flushed buffer 530 with 1000 items → ./cache/cath_buffered/part_530.pkl
# Flushed buffer 531 with 1000 items → ./cache/cath_buffered/part_531.pkl
# Flushed buffer 532 with 1000 items → ./cache/cath_buffered/part_532.pkl
# Flushed buffer 533 with 1000 items → ./cache/cath_buffered/part_533.pkl
# Flushed buffer 534 with 1000 items → ./cache/cath_buffered/part_534.pkl
# Flushed buffer 535 with 1000 items → ./cache/cath_buffered/part_535.pkl
# Flushed buffer 536 with 1000 items → ./cache/cath_buffered/part_536.pkl
# Flushed buffer 537 with 1000 items → ./cache/cath_buffered/part_537.pkl
# Flushed buffer 538 with 1000 items → ./cache/cath_buffered/part_538.pkl
# Flushed buffer 539 with 1000 items → ./cache/cath_buffered/part_539.pkl
# Flushed buffer 540 with 1000 items → ./cache/cath_buffered/part_540.pkl
# Flushed buffer 541 with 1000 items → ./cache/cath_buffered/part_541.pkl
# Flushed buffer 542 with 1000 items → ./cache/cath_buffered/part_542.pkl
# Flushed buffer 543 with 1000 items → ./cache/cath_buffered/part_543.pkl
# Flushed buffer 544 with 1000 items → ./cache/cath_buffered/part_544.pkl
# Flushed buffer 545 with 1000 items → ./cache/cath_buffered/part_545.pkl
# Flushed buffer 546 with 1000 items → ./cache/cath_buffered/part_546.pkl
# Flushed buffer 547 with 1000 items → ./cache/cath_buffered/part_547.pkl
# Flushed buffer 548 with 1000 items → ./cache/cath_buffered/part_548.pkl
# Flushed buffer 549 with 1000 items → ./cache/cath_buffered/part_549.pkl
# Flushed buffer 550 with 1000 items → ./cache/cath_buffered/part_550.pkl
# Flushed buffer 551 with 1000 items → ./cache/cath_buffered/part_551.pkl
# Flushed buffer 552 with 1000 items → ./cache/cath_buffered/part_552.pkl
# Flushed buffer 553 with 1000 items → ./cache/cath_buffered/part_553.pkl
# Flushed buffer 554 with 1000 items → ./cache/cath_buffered/part_554.pkl
# Flushed buffer 555 with 1000 items → ./cache/cath_buffered/part_555.pkl
# Flushed buffer 556 with 1000 items → ./cache/cath_buffered/part_556.pkl
# Flushed buffer 557 with 1000 items → ./cache/cath_buffered/part_557.pkl
# Flushed buffer 558 with 1000 items → ./cache/cath_buffered/part_558.pkl
# Flushed buffer 559 with 1000 items → ./cache/cath_buffered/part_559.pkl
# Flushed buffer 560 with 1000 items → ./cache/cath_buffered/part_560.pkl
# Flushed buffer 561 with 1000 items → ./cache/cath_buffered/part_561.pkl
# Flushed buffer 562 with 1000 items → ./cache/cath_buffered/part_562.pkl
# Flushed buffer 563 with 1000 items → ./cache/cath_buffered/part_563.pkl
# Flushed buffer 564 with 1000 items → ./cache/cath_buffered/part_564.pkl
# Flushed buffer 565 with 1000 items → ./cache/cath_buffered/part_565.pkl
# Flushed buffer 566 with 1000 items → ./cache/cath_buffered/part_566.pkl
# Flushed buffer 567 with 1000 items → ./cache/cath_buffered/part_567.pkl
# Flushed buffer 568 with 1000 items → ./cache/cath_buffered/part_568.pkl
# Flushed buffer 569 with 1000 items → ./cache/cath_buffered/part_569.pkl
# Flushed buffer 570 with 1000 items → ./cache/cath_buffered/part_570.pkl
# Flushed buffer 571 with 1000 items → ./cache/cath_buffered/part_571.pkl
# Flushed buffer 572 with 1000 items → ./cache/cath_buffered/part_572.pkl
# Flushed buffer 573 with 1000 items → ./cache/cath_buffered/part_573.pkl
# Flushed buffer 574 with 1000 items → ./cache/cath_buffered/part_574.pkl
# Flushed buffer 575 with 1000 items → ./cache/cath_buffered/part_575.pkl
# Flushed buffer 576 with 1000 items → ./cache/cath_buffered/part_576.pkl
# Flushed buffer 577 with 1000 items → ./cache/cath_buffered/part_577.pkl
# Flushed buffer 578 with 1000 items → ./cache/cath_buffered/part_578.pkl
# Flushed buffer 579 with 1000 items → ./cache/cath_buffered/part_579.pkl
# Flushed buffer 580 with 1000 items → ./cache/cath_buffered/part_580.pkl
# Flushed buffer 581 with 1000 items → ./cache/cath_buffered/part_581.pkl
# Flushed buffer 582 with 1000 items → ./cache/cath_buffered/part_582.pkl
# Flushed buffer 583 with 1000 items → ./cache/cath_buffered/part_583.pkl
# Flushed buffer 584 with 1000 items → ./cache/cath_buffered/part_584.pkl
# Flushed buffer 585 with 1000 items → ./cache/cath_buffered/part_585.pkl
# Flushed buffer 586 with 1000 items → ./cache/cath_buffered/part_586.pkl
# Flushed buffer 587 with 1000 items → ./cache/cath_buffered/part_587.pkl
# Flushed buffer 588 with 1000 items → ./cache/cath_buffered/part_588.pkl
# Flushed buffer 589 with 1000 items → ./cache/cath_buffered/part_589.pkl
# Flushed buffer 590 with 1000 items → ./cache/cath_buffered/part_590.pkl
# Flushed buffer 591 with 1000 items → ./cache/cath_buffered/part_591.pkl
# Flushed buffer 592 with 1000 items → ./cache/cath_buffered/part_592.pkl
# Flushed buffer 593 with 1000 items → ./cache/cath_buffered/part_593.pkl
# Flushed buffer 594 with 1000 items → ./cache/cath_buffered/part_594.pkl
# Flushed buffer 595 with 1000 items → ./cache/cath_buffered/part_595.pkl
# Flushed buffer 596 with 1000 items → ./cache/cath_buffered/part_596.pkl
# Flushed buffer 597 with 1000 items → ./cache/cath_buffered/part_597.pkl
# Flushed buffer 598 with 1000 items → ./cache/cath_buffered/part_598.pkl
# Flushed buffer 599 with 1000 items → ./cache/cath_buffered/part_599.pkl
# Flushed buffer 600 with 1000 items → ./cache/cath_buffered/part_600.pkl
# Flushed buffer 601 with 1000 items → ./cache/cath_buffered/part_601.pkl
# Flushed buffer 602 with 1000 items → ./cache/cath_buffered/part_602.pkl
# Flushed buffer 603 with 1000 items → ./cache/cath_buffered/part_603.pkl
# Flushed buffer 604 with 1000 items → ./cache/cath_buffered/part_604.pkl
# Flushed buffer 605 with 1000 items → ./cache/cath_buffered/part_605.pkl
# Flushed buffer 606 with 1000 items → ./cache/cath_buffered/part_606.pkl
# Flushed buffer 607 with 1000 items → ./cache/cath_buffered/part_607.pkl
# Flushed buffer 608 with 1000 items → ./cache/cath_buffered/part_608.pkl
# Flushed buffer 609 with 1000 items → ./cache/cath_buffered/part_609.pkl
# Flushed buffer 610 with 1000 items → ./cache/cath_buffered/part_610.pkl
# Flushed buffer 611 with 1000 items → ./cache/cath_buffered/part_611.pkl
# Flushed buffer 612 with 1000 items → ./cache/cath_buffered/part_612.pkl
# Flushed buffer 613 with 1000 items → ./cache/cath_buffered/part_613.pkl
# Flushed buffer 614 with 1000 items → ./cache/cath_buffered/part_614.pkl
# Flushed buffer 615 with 1000 items → ./cache/cath_buffered/part_615.pkl
# Flushed buffer 616 with 1000 items → ./cache/cath_buffered/part_616.pkl
# Flushed buffer 617 with 1000 items → ./cache/cath_buffered/part_617.pkl
# Flushed buffer 618 with 1000 items → ./cache/cath_buffered/part_618.pkl
# Flushed buffer 619 with 1000 items → ./cache/cath_buffered/part_619.pkl
# Flushed buffer 620 with 1000 items → ./cache/cath_buffered/part_620.pkl
# Flushed buffer 621 with 1000 items → ./cache/cath_buffered/part_621.pkl
# Flushed buffer 622 with 1000 items → ./cache/cath_buffered/part_622.pkl
# Flushed buffer 623 with 1000 items → ./cache/cath_buffered/part_623.pkl
# Flushed buffer 624 with 1000 items → ./cache/cath_buffered/part_624.pkl
# Flushed buffer 625 with 1000 items → ./cache/cath_buffered/part_625.pkl
# Flushed buffer 626 with 1000 items → ./cache/cath_buffered/part_626.pkl
# Flushed buffer 627 with 1000 items → ./cache/cath_buffered/part_627.pkl
# Flushed buffer 628 with 1000 items → ./cache/cath_buffered/part_628.pkl
# Flushed buffer 629 with 1000 items → ./cache/cath_buffered/part_629.pkl
# Flushed buffer 630 with 1000 items → ./cache/cath_buffered/part_630.pkl
# Flushed buffer 631 with 1000 items → ./cache/cath_buffered/part_631.pkl
# Flushed buffer 632 with 1000 items → ./cache/cath_buffered/part_632.pkl
# Flushed buffer 633 with 1000 items → ./cache/cath_buffered/part_633.pkl
# Flushed buffer 634 with 1000 items → ./cache/cath_buffered/part_634.pkl
# Flushed buffer 635 with 1000 items → ./cache/cath_buffered/part_635.pkl
# Flushed buffer 636 with 1000 items → ./cache/cath_buffered/part_636.pkl
# Flushed buffer 637 with 1000 items → ./cache/cath_buffered/part_637.pkl
# Flushed buffer 638 with 1000 items → ./cache/cath_buffered/part_638.pkl
# Flushed buffer 639 with 1000 items → ./cache/cath_buffered/part_639.pkl
# Flushed buffer 640 with 1000 items → ./cache/cath_buffered/part_640.pkl
# Flushed buffer 641 with 1000 items → ./cache/cath_buffered/part_641.pkl
# Flushed buffer 642 with 1000 items → ./cache/cath_buffered/part_642.pkl
# Flushed buffer 643 with 1000 items → ./cache/cath_buffered/part_643.pkl
# Flushed buffer 644 with 1000 items → ./cache/cath_buffered/part_644.pkl
# Flushed buffer 645 with 1000 items → ./cache/cath_buffered/part_645.pkl
# Flushed buffer 646 with 1000 items → ./cache/cath_buffered/part_646.pkl
# Flushed buffer 647 with 1000 items → ./cache/cath_buffered/part_647.pkl
# Flushed buffer 648 with 1000 items → ./cache/cath_buffered/part_648.pkl
# Flushed buffer 649 with 1000 items → ./cache/cath_buffered/part_649.pkl
# Flushed buffer 650 with 1000 items → ./cache/cath_buffered/part_650.pkl
# Flushed buffer 651 with 1000 items → ./cache/cath_buffered/part_651.pkl
# Flushed buffer 652 with 1000 items → ./cache/cath_buffered/part_652.pkl
# Flushed buffer 653 with 1000 items → ./cache/cath_buffered/part_653.pkl
# Flushed buffer 654 with 1000 items → ./cache/cath_buffered/part_654.pkl
# Flushed buffer 655 with 1000 items → ./cache/cath_buffered/part_655.pkl
# Flushed buffer 656 with 1000 items → ./cache/cath_buffered/part_656.pkl
# Flushed buffer 657 with 1000 items → ./cache/cath_buffered/part_657.pkl
# Flushed buffer 658 with 1000 items → ./cache/cath_buffered/part_658.pkl
# Flushed buffer 659 with 1000 items → ./cache/cath_buffered/part_659.pkl
# Flushed buffer 660 with 1000 items → ./cache/cath_buffered/part_660.pkl
# Flushed buffer 661 with 1000 items → ./cache/cath_buffered/part_661.pkl
# Flushed buffer 662 with 1000 items → ./cache/cath_buffered/part_662.pkl
# Flushed buffer 663 with 1000 items → ./cache/cath_buffered/part_663.pkl
# Flushed buffer 664 with 1000 items → ./cache/cath_buffered/part_664.pkl
# Flushed buffer 665 with 1000 items → ./cache/cath_buffered/part_665.pkl
# Flushed buffer 666 with 1000 items → ./cache/cath_buffered/part_666.pkl
# Flushed buffer 667 with 1000 items → ./cache/cath_buffered/part_667.pkl
# ...
# Flushed buffer 3390 with 1000 items → ./cache/cath_buffered/part_3390.pkl
# Flushed buffer 3391 with 1000 items → ./cache/cath_buffered/part_3391.pkl
# Flushed buffer 3392 with 1000 items → ./cache/cath_buffered/part_3392.pkl
# Flushed buffer 3393 with 1000 items → ./cache/cath_buffered/part_3393.pkl
# Flushed buffer 3394 with 1000 items → ./cache/cath_buffered/part_3394.pkl
# Flushed buffer 3395 with 1000 items → ./cache/cath_buffered/part_3395.pkl
# Flushed buffer 3396 with 1000 items → ./cache/cath_buffered/part_3396.pkl
# Flushed buffer 3397 with 1000 items → ./cache/cath_buffered/part_3397.pkl
# Flushed buffer 3398 with 1000 items → ./cache/cath_buffered/part_3398.pkl
# Flushed buffer 3399 with 1000 items → ./cache/cath_buffered/part_3399.pkl
# Flushed buffer 3400 with 1000 items → ./cache/cath_buffered/part_3400.pkl
# Flushed buffer 3401 with 1000 items → ./cache/cath_buffered/part_3401.pkl
# Flushed buffer 3402 with 1000 items → ./cache/cath_buffered/part_3402.pkl
# Flushed buffer 3403 with 1000 items → ./cache/cath_buffered/part_3403.pkl
# Flushed buffer 3404 with 1000 items → ./cache/cath_buffered/part_3404.pkl
# Flushed buffer 3405 with 1000 items → ./cache/cath_buffered/part_3405.pkl
# Flushed buffer 3406 with 1000 items → ./cache/cath_buffered/part_3406.pkl
# Flushed buffer 3407 with 1000 items → ./cache/cath_buffered/part_3407.pkl
# Flushed buffer 3408 with 1000 items → ./cache/cath_buffered/part_3408.pkl
# Flushed buffer 3409 with 1000 items → ./cache/cath_buffered/part_3409.pkl
# Flushed buffer 3410 with 1000 items → ./cache/cath_buffered/part_3410.pkl
# Flushed buffer 3411 with 1000 items → ./cache/cath_buffered/part_3411.pkl
# Flushed buffer 3412 with 1000 items → ./cache/cath_buffered/part_3412.pkl
# Flushed buffer 3413 with 1000 items → ./cache/cath_buffered/part_3413.pkl
# Flushed buffer 3414 with 1000 items → ./cache/cath_buffered/part_3414.pkl
# Flushed buffer 3415 with 1000 items → ./cache/cath_buffered/part_3415.pkl
# Flushed buffer 3416 with 1000 items → ./cache/cath_buffered/part_3416.pkl
# Flushed buffer 3417 with 1000 items → ./cache/cath_buffered/part_3417.pkl
# Flushed buffer 3418 with 1000 items → ./cache/cath_buffered/part_3418.pkl
# Flushed buffer 3419 with 1000 items → ./cache/cath_buffered/part_3419.pkl
# Flushed buffer 3420 with 1000 items → ./cache/cath_buffered/part_3420.pkl
# Flushed buffer 3421 with 1000 items → ./cache/cath_buffered/part_3421.pkl
# Flushed buffer 3422 with 1000 items → ./cache/cath_buffered/part_3422.pkl
# Flushed buffer 3423 with 1000 items → ./cache/cath_buffered/part_3423.pkl
# Flushed buffer 3424 with 1000 items → ./cache/cath_buffered/part_3424.pkl
# Flushed buffer 3425 with 1000 items → ./cache/cath_buffered/part_3425.pkl
# Flushed buffer 3426 with 1000 items → ./cache/cath_buffered/part_3426.pkl
# Flushed buffer 3427 with 1000 items → ./cache/cath_buffered/part_3427.pkl
# Flushed buffer 3428 with 1000 items → ./cache/cath_buffered/part_3428.pkl
# Flushed buffer 3429 with 1000 items → ./cache/cath_buffered/part_3429.pkl
# Flushed buffer 3430 with 1000 items → ./cache/cath_buffered/part_3430.pkl
# Flushed buffer 3431 with 1000 items → ./cache/cath_buffered/part_3431.pkl
# Flushed buffer 3432 with 1000 items → ./cache/cath_buffered/part_3432.pkl
# Flushed buffer 3433 with 1000 items → ./cache/cath_buffered/part_3433.pkl
# Flushed buffer 3434 with 1000 items → ./cache/cath_buffered/part_3434.pkl
# Flushed buffer 3435 with 1000 items → ./cache/cath_buffered/part_3435.pkl
# Flushed buffer 3436 with 1000 items → ./cache/cath_buffered/part_3436.pkl
# Flushed buffer 3437 with 1000 items → ./cache/cath_buffered/part_3437.pkl
# Flushed buffer 3438 with 1000 items → ./cache/cath_buffered/part_3438.pkl
# Flushed buffer 3439 with 1000 items → ./cache/cath_buffered/part_3439.pkl
# Flushed buffer 3440 with 1000 items → ./cache/cath_buffered/part_3440.pkl
# Flushed buffer 3441 with 1000 items → ./cache/cath_buffered/part_3441.pkl
# Flushed buffer 3442 with 1000 items → ./cache/cath_buffered/part_3442.pkl
# Flushed buffer 3443 with 1000 items → ./cache/cath_buffered/part_3443.pkl
# Flushed buffer 3444 with 1000 items → ./cache/cath_buffered/part_3444.pkl
# Flushed buffer 3445 with 1000 items → ./cache/cath_buffered/part_3445.pkl
# Flushed buffer 3446 with 1000 items → ./cache/cath_buffered/part_3446.pkl
# Flushed buffer 3447 with 1000 items → ./cache/cath_buffered/part_3447.pkl
# Flushed buffer 3448 with 1000 items → ./cache/cath_buffered/part_3448.pkl
# Flushed buffer 3449 with 1000 items → ./cache/cath_buffered/part_3449.pkl
# Flushed buffer 3450 with 1000 items → ./cache/cath_buffered/part_3450.pkl
# Flushed buffer 3451 with 1000 items → ./cache/cath_buffered/part_3451.pkl
# Flushed buffer 3452 with 1000 items → ./cache/cath_buffered/part_3452.pkl
# Flushed buffer 3453 with 1000 items → ./cache/cath_buffered/part_3453.pkl
# Flushed buffer 3454 with 1000 items → ./cache/cath_buffered/part_3454.pkl
# Flushed buffer 3455 with 1000 items → ./cache/cath_buffered/part_3455.pkl
# Flushed buffer 3456 with 1000 items → ./cache/cath_buffered/part_3456.pkl
# Flushed buffer 3457 with 1000 items → ./cache/cath_buffered/part_3457.pkl
# Flushed buffer 3458 with 1000 items → ./cache/cath_buffered/part_3458.pkl
# Flushed buffer 3459 with 1000 items → ./cache/cath_buffered/part_3459.pkl
# Flushed buffer 3460 with 1000 items → ./cache/cath_buffered/part_3460.pkl
# Flushed buffer 3461 with 1000 items → ./cache/cath_buffered/part_3461.pkl
# Flushed buffer 3462 with 1000 items → ./cache/cath_buffered/part_3462.pkl
# Flushed buffer 3463 with 1000 items → ./cache/cath_buffered/part_3463.pkl
# Flushed buffer 3464 with 1000 items → ./cache/cath_buffered/part_3464.pkl
# Flushed buffer 3465 with 1000 items → ./cache/cath_buffered/part_3465.pkl
# Flushed buffer 3466 with 1000 items → ./cache/cath_buffered/part_3466.pkl
# Flushed buffer 3467 with 1000 items → ./cache/cath_buffered/part_3467.pkl
# Flushed buffer 3468 with 1000 items → ./cache/cath_buffered/part_3468.pkl
# Flushed buffer 3469 with 1000 items → ./cache/cath_buffered/part_3469.pkl
# Flushed buffer 3470 with 1000 items → ./cache/cath_buffered/part_3470.pkl
# Flushed buffer 3471 with 1000 items → ./cache/cath_buffered/part_3471.pkl
# Flushed buffer 3472 with 1000 items → ./cache/cath_buffered/part_3472.pkl
# Flushed buffer 3473 with 1000 items → ./cache/cath_buffered/part_3473.pkl
# Flushed buffer 3474 with 1000 items → ./cache/cath_buffered/part_3474.pkl
# Flushed buffer 3475 with 1000 items → ./cache/cath_buffered/part_3475.pkl
# Flushed buffer 3476 with 1000 items → ./cache/cath_buffered/part_3476.pkl
# Flushed buffer 3477 with 1000 items → ./cache/cath_buffered/part_3477.pkl
# Flushed buffer 3478 with 1000 items → ./cache/cath_buffered/part_3478.pkl
# Flushed buffer 3479 with 1000 items → ./cache/cath_buffered/part_3479.pkl
# Flushed buffer 3480 with 1000 items → ./cache/cath_buffered/part_3480.pkl
# Flushed buffer 3481 with 1000 items → ./cache/cath_buffered/part_3481.pkl
# Flushed buffer 3482 with 1000 items → ./cache/cath_buffered/part_3482.pkl
# Flushed buffer 3483 with 1000 items → ./cache/cath_buffered/part_3483.pkl
# Flushed buffer 3484 with 1000 items → ./cache/cath_buffered/part_3484.pkl
# Flushed buffer 3485 with 1000 items → ./cache/cath_buffered/part_3485.pkl
# Flushed buffer 3486 with 1000 items → ./cache/cath_buffered/part_3486.pkl
# Flushed buffer 3487 with 1000 items → ./cache/cath_buffered/part_3487.pkl
# Flushed buffer 3488 with 1000 items → ./cache/cath_buffered/part_3488.pkl
# Flushed buffer 3489 with 1000 items → ./cache/cath_buffered/part_3489.pkl
# Flushed buffer 3490 with 1000 items → ./cache/cath_buffered/part_3490.pkl
# Flushed buffer 3491 with 1000 items → ./cache/cath_buffered/part_3491.pkl
# Flushed buffer 3492 with 1000 items → ./cache/cath_buffered/part_3492.pkl
# Flushed buffer 3493 with 1000 items → ./cache/cath_buffered/part_3493.pkl
# Flushed buffer 3494 with 1000 items → ./cache/cath_buffered/part_3494.pkl
# Flushed buffer 3495 with 1000 items → ./cache/cath_buffered/part_3495.pkl
# Flushed buffer 3496 with 1000 items → ./cache/cath_buffered/part_3496.pkl
# Flushed buffer 3497 with 1000 items → ./cache/cath_buffered/part_3497.pkl
# Flushed buffer 3498 with 1000 items → ./cache/cath_buffered/part_3498.pkl
# Flushed buffer 3499 with 1000 items → ./cache/cath_buffered/part_3499.pkl
# Flushed buffer 3500 with 1000 items → ./cache/cath_buffered/part_3500.pkl
# Flushed buffer 3501 with 1000 items → ./cache/cath_buffered/part_3501.pkl
# Flushed buffer 3502 with 1000 items → ./cache/cath_buffered/part_3502.pkl
# Flushed buffer 3503 with 1000 items → ./cache/cath_buffered/part_3503.pkl
# Flushed buffer 3504 with 1000 items → ./cache/cath_buffered/part_3504.pkl
# Flushed buffer 3505 with 1000 items → ./cache/cath_buffered/part_3505.pkl
# Flushed buffer 3506 with 1000 items → ./cache/cath_buffered/part_3506.pkl
# Flushed buffer 3507 with 1000 items → ./cache/cath_buffered/part_3507.pkl
# Flushed buffer 3508 with 1000 items → ./cache/cath_buffered/part_3508.pkl
# Flushed buffer 3509 with 1000 items → ./cache/cath_buffered/part_3509.pkl
# Flushed buffer 3510 with 1000 items → ./cache/cath_buffered/part_3510.pkl
# Flushed buffer 3511 with 1000 items → ./cache/cath_buffered/part_3511.pkl
# Flushed buffer 3512 with 1000 items → ./cache/cath_buffered/part_3512.pkl
# Flushed buffer 3513 with 1000 items → ./cache/cath_buffered/part_3513.pkl
# Flushed buffer 3514 with 1000 items → ./cache/cath_buffered/part_3514.pkl
# Flushed buffer 3515 with 1000 items → ./cache/cath_buffered/part_3515.pkl
# Flushed buffer 3516 with 1000 items → ./cache/cath_buffered/part_3516.pkl
# Flushed buffer 3517 with 1000 items → ./cache/cath_buffered/part_3517.pkl
# Flushed buffer 3518 with 1000 items → ./cache/cath_buffered/part_3518.pkl
# Flushed buffer 3519 with 1000 items → ./cache/cath_buffered/part_3519.pkl
# Flushed buffer 3520 with 1000 items → ./cache/cath_buffered/part_3520.pkl
# Flushed buffer 3521 with 1000 items → ./cache/cath_buffered/part_3521.pkl
# Flushed buffer 3522 with 1000 items → ./cache/cath_buffered/part_3522.pkl
# Flushed buffer 3523 with 1000 items → ./cache/cath_buffered/part_3523.pkl
# Flushed buffer 3524 with 1000 items → ./cache/cath_buffered/part_3524.pkl
# Flushed buffer 3525 with 1000 items → ./cache/cath_buffered/part_3525.pkl
# Flushed buffer 3526 with 1000 items → ./cache/cath_buffered/part_3526.pkl
# Flushed buffer 3527 with 1000 items → ./cache/cath_buffered/part_3527.pkl
# Flushed buffer 3528 with 1000 items → ./cache/cath_buffered/part_3528.pkl
# Flushed buffer 3529 with 1000 items → ./cache/cath_buffered/part_3529.pkl
# Flushed buffer 3530 with 1000 items → ./cache/cath_buffered/part_3530.pkl
# Flushed buffer 3531 with 1000 items → ./cache/cath_buffered/part_3531.pkl
# Flushed buffer 3532 with 1000 items → ./cache/cath_buffered/part_3532.pkl
# Flushed buffer 3533 with 1000 items → ./cache/cath_buffered/part_3533.pkl
# Flushed buffer 3534 with 1000 items → ./cache/cath_buffered/part_3534.pkl
# Flushed buffer 3535 with 1000 items → ./cache/cath_buffered/part_3535.pkl
# Flushed buffer 3536 with 1000 items → ./cache/cath_buffered/part_3536.pkl
# Flushed buffer 3537 with 1000 items → ./cache/cath_buffered/part_3537.pkl
# Flushed buffer 3538 with 1000 items → ./cache/cath_buffered/part_3538.pkl
# Flushed buffer 3539 with 1000 items → ./cache/cath_buffered/part_3539.pkl
# Flushed buffer 3540 with 1000 items → ./cache/cath_buffered/part_3540.pkl
# Flushed buffer 3541 with 1000 items → ./cache/cath_buffered/part_3541.pkl
# Flushed buffer 3542 with 1000 items → ./cache/cath_buffered/part_3542.pkl
# Flushed buffer 3543 with 1000 items → ./cache/cath_buffered/part_3543.pkl
# Flushed buffer 3544 with 1000 items → ./cache/cath_buffered/part_3544.pkl
# Flushed buffer 3545 with 1000 items → ./cache/cath_buffered/part_3545.pkl
# Flushed buffer 3546 with 1000 items → ./cache/cath_buffered/part_3546.pkl
# Flushed buffer 3547 with 1000 items → ./cache/cath_buffered/part_3547.pkl
# Flushed buffer 3548 with 1000 items → ./cache/cath_buffered/part_3548.pkl
# Flushed buffer 3549 with 1000 items → ./cache/cath_buffered/part_3549.pkl
# Flushed buffer 3550 with 1000 items → ./cache/cath_buffered/part_3550.pkl
# Flushed buffer 3551 with 1000 items → ./cache/cath_buffered/part_3551.pkl
# Flushed buffer 3552 with 1000 items → ./cache/cath_buffered/part_3552.pkl
# Flushed buffer 3553 with 1000 items → ./cache/cath_buffered/part_3553.pkl
# Flushed buffer 3554 with 1000 items → ./cache/cath_buffered/part_3554.pkl
# Flushed buffer 3555 with 1000 items → ./cache/cath_buffered/part_3555.pkl
# Flushed buffer 3556 with 1000 items → ./cache/cath_buffered/part_3556.pkl
# Flushed buffer 3557 with 1000 items → ./cache/cath_buffered/part_3557.pkl
# Flushed buffer 3558 with 1000 items → ./cache/cath_buffered/part_3558.pkl
# Flushed buffer 3559 with 1000 items → ./cache/cath_buffered/part_3559.pkl
# Flushed buffer 3560 with 1000 items → ./cache/cath_buffered/part_3560.pkl
# Flushed buffer 3561 with 1000 items → ./cache/cath_buffered/part_3561.pkl
# Flushed buffer 3562 with 1000 items → ./cache/cath_buffered/part_3562.pkl
# Flushed buffer 3563 with 1000 items → ./cache/cath_buffered/part_3563.pkl
# Flushed buffer 3564 with 1000 items → ./cache/cath_buffered/part_3564.pkl
# Flushed buffer 3565 with 1000 items → ./cache/cath_buffered/part_3565.pkl
# Flushed buffer 3566 with 1000 items → ./cache/cath_buffered/part_3566.pkl
# Flushed buffer 3567 with 1000 items → ./cache/cath_buffered/part_3567.pkl
# Flushed buffer 3568 with 1000 items → ./cache/cath_buffered/part_3568.pkl
# Flushed buffer 3569 with 1000 items → ./cache/cath_buffered/part_3569.pkl
# Flushed buffer 3570 with 1000 items → ./cache/cath_buffered/part_3570.pkl
# Flushed buffer 3571 with 1000 items → ./cache/cath_buffered/part_3571.pkl
# Flushed buffer 3572 with 1000 items → ./cache/cath_buffered/part_3572.pkl
# Flushed buffer 3573 with 1000 items → ./cache/cath_buffered/part_3573.pkl
# Flushed buffer 3574 with 1000 items → ./cache/cath_buffered/part_3574.pkl
# Flushed buffer 3575 with 1000 items → ./cache/cath_buffered/part_3575.pkl
# Flushed buffer 3576 with 1000 items → ./cache/cath_buffered/part_3576.pkl
# Flushed buffer 3577 with 1000 items → ./cache/cath_buffered/part_3577.pkl
# Flushed buffer 3578 with 1000 items → ./cache/cath_buffered/part_3578.pkl
# Flushed buffer 3579 with 1000 items → ./cache/cath_buffered/part_3579.pkl
# Flushed buffer 3580 with 1000 items → ./cache/cath_buffered/part_3580.pkl
# Flushed buffer 3581 with 1000 items → ./cache/cath_buffered/part_3581.pkl
# Flushed buffer 3582 with 1000 items → ./cache/cath_buffered/part_3582.pkl
# Flushed buffer 3583 with 1000 items → ./cache/cath_buffered/part_3583.pkl
# Flushed buffer 3584 with 1000 items → ./cache/cath_buffered/part_3584.pkl
# Flushed buffer 3585 with 1000 items → ./cache/cath_buffered/part_3585.pkl
# Flushed buffer 3586 with 1000 items → ./cache/cath_buffered/part_3586.pkl
# Flushed buffer 3587 with 1000 items → ./cache/cath_buffered/part_3587.pkl
# Flushed buffer 3588 with 1000 items → ./cache/cath_buffered/part_3588.pkl
# Flushed buffer 3589 with 1000 items → ./cache/cath_buffered/part_3589.pkl
# Flushed buffer 3590 with 1000 items → ./cache/cath_buffered/part_3590.pkl
# Flushed buffer 3591 with 1000 items → ./cache/cath_buffered/part_3591.pkl
# Flushed buffer 3592 with 1000 items → ./cache/cath_buffered/part_3592.pkl
# Flushed buffer 3593 with 1000 items → ./cache/cath_buffered/part_3593.pkl
# Flushed buffer 3594 with 1000 items → ./cache/cath_buffered/part_3594.pkl
# Flushed buffer 3595 with 1000 items → ./cache/cath_buffered/part_3595.pkl
# Flushed buffer 3596 with 1000 items → ./cache/cath_buffered/part_3596.pkl
# Flushed buffer 3597 with 1000 items → ./cache/cath_buffered/part_3597.pkl
# Flushed buffer 3598 with 1000 items → ./cache/cath_buffered/part_3598.pkl
# Flushed buffer 3599 with 1000 items → ./cache/cath_buffered/part_3599.pkl
# Flushed buffer 3600 with 1000 items → ./cache/cath_buffered/part_3600.pkl
# Flushed buffer 3601 with 1000 items → ./cache/cath_buffered/part_3601.pkl
# Flushed buffer 3602 with 1000 items → ./cache/cath_buffered/part_3602.pkl
# Flushed buffer 3603 with 1000 items → ./cache/cath_buffered/part_3603.pkl
# Flushed buffer 3604 with 269 items → ./cache/cath_buffered/part_3604.pkl
#  Done. Total buffers flushed: 3605

# %%
from cache_utils import load_cached_parts
from dataset import ProteinPairDataset

# Step 1: Load and merge buffered part_*.pkl files
features, labels = load_cached_parts("./cache/cath_buffered")

# Step 2: Pass them into your dataset directly
dataset = ProteinPairDataset(features=features, labels=labels)
# Out:
# Loading 3605 cached parts from: ./cache/cath_buffered

# %%
2685*2684/2
# Out:
# 3603270.0

# %%
from cache_utils import cache_pairwise_data
import time

# caching proteins for fast prototyping
tic = time.time_ns()
num_items = 2685
cache_pairwise_data(cath_df.head(num_items),cache_dir="cache/test_cache", buffer_limit_mb=10)
tac = time.time_ns()
print((tac-tic)/(10**6),"ms")

# %%
# # Train logistic regression
# model_logistic = train_model(cath_df, hidden_dim=None, num_epochs=5, batch_size=8)

# Train small neural net
model_fcn = train_model(cath_df.head(150), hidden_dim=64, num_epochs=5, batch_size=8)
